# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %%
df=pd.read_csv('/home/siva/Downloads/heart_failure_clinical_records_dataset.csv')
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df['age_z']=(df['age']-df['age'].mean())/df['age'].std()
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df=df[(df['age_z']<3) | (df['age_z']<-3)]
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
z_scores=np.abs(stats.zscore(df))
z_scores
# Out:
#           age   anaemia  creatinine_phosphokinase  diabetes  \
# 0    1.192945  0.871105                  0.000166  0.847579
# 1    0.491279  0.871105                  7.514640  0.847579
# 2    0.350833  0.871105                  0.449939  0.847579
# 3    0.912335  1.147968                  0.486071  0.847579
# 4    0.350833  1.147968                  0.435486  1.179830
# ..        ...       ...                       ...       ...
# 294  0.098199  0.871105                  0.537688  1.179830
# 295  0.491279  0.871105                  1.278215  0.847579
# 296  1.333392  0.871105                  1.525979  1.179830
# 297  1.333392  0.871105                  1.890398  0.847579
# 298  0.912335  0.871105                  0.398321  0.847579
#
#      ejection_fraction  high_blood_pressure     platelets  serum_creatinine  \
# 0             1.530560             1.359272  1.681648e-02          0.490057
# 1             0.007077             0.735688  7.535660e-09          0.284552
# ...

# %%
df=df[(z_scores<3).all(axis=1)]
df.reset_index(inplace=True,drop=True)
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    65.0        0                       146         0                 20
# 2    50.0        1                       111         0                 20
# 3    90.0        1                        47         0                 40
# 4    75.0        1                       246         0                 15
# ..    ...      ...                       ...       ...                ...
# 275  63.0        1                       103         1                 35
# 276  62.0        0                        61         1                 38
# 277  55.0        0                      1820         0                 38
# 278  45.0        0                      2413         0                 38
# 279  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
scaler=MinMaxScaler()
df_scaled=scaler.fit_transform(df)
df_scaled=pd.DataFrame(df_scaled,columns=df.columns)
df_scaled
# Out:
#           age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    0.636364      0.0                  0.201732       0.0           0.117647
# 1    0.454545      0.0                  0.044388       0.0           0.117647
# 2    0.181818      1.0                  0.031757       0.0           0.117647
# 3    0.909091      1.0                  0.008661       0.0           0.509804
# 4    0.636364      1.0                  0.080476       0.0           0.019608
# ..        ...      ...                       ...       ...                ...
# 275  0.418182      1.0                  0.028870       1.0           0.411765
# 276  0.400000      0.0                  0.013713       1.0           0.470588
# 277  0.272727      0.0                  0.648502       0.0           0.470588
# 278  0.090909      0.0                  0.862505       0.0           0.470588
# 279  0.181818      0.0                  0.062432       0.0           0.607843
#
# ...

# %%
models={
    'svc':{
        'model':SVC(gamma='auto'),
        'params':{
            'kernel':['linear', 'poly', 'rbf', 'sigmoid'],
            'C':[1,10,20]
        }
    },
    'random_forest':{
        'model':RandomForestClassifier(),
        'params':{
            'n_estimators':[50,100,250,500,1000,1500]
        }
    },
    'logistic_regression':{
        'model':LogisticRegression(),
        'params':{
            'C':[1,10,20]
        }
    },
    'gaussian_nb':{
        'model':GaussianNB(),
        'params':{
            
        }
    },
    'decision_tree':{
        'model':DecisionTreeClassifier(),
        'params':{
            'criterion':['gini', 'entropy', 'log_loss']
        }
    }
}

# %%
score=[]
for model_name,model_params in models.items():
    gsv_clv=GridSearchCV(model_params['model'],\
        model_params['params'],cv=5,return_train_score=False)
    gsv_clv.fit(df_scaled.drop(['DEATH_EVENT'],axis=1),\
                df_scaled['DEATH_EVENT'])
    score.append([model_name,gsv_clv.best_score_,\
                  gsv_clv.best_params_])
score
# Out:
# [['svc', 0.775, {'C': 20, 'kernel': 'linear'}],
#  ['random_forest', 0.7035714285714286, {'n_estimators': 50}],
#  ['logistic_regression', 0.7928571428571429, {'C': 1}],
#  ['gaussian_nb', 0.7928571428571429, {}],
#  ['decision_tree', 0.6535714285714287, {'criterion': 'gini'}]]

# %%
df_score=pd.DataFrame(score,columns=['model','best_score','best_params'])
df_score
# Out:
#                  model  best_score                    best_params
# 0                  svc    0.775000  {'C': 20, 'kernel': 'linear'}
# 1        random_forest    0.703571           {'n_estimators': 50}
# 2  logistic_regression    0.792857                       {'C': 1}
# 3          gaussian_nb    0.792857                             {}
# 4        decision_tree    0.653571          {'criterion': 'gini'}

# %%
pca=PCA(n_components=0.95)

# %%
df_pcaed=pca.fit_transform(df_scaled.drop(['DEATH_EVENT'],axis=1))
df_pcaed
# Out:
# array([[-0.18198653,  0.23527803,  0.86128511, ...,  0.38420857,
#         -0.22619467, -0.01016498],
#        [-0.97417963, -0.09597636,  0.04736647, ...,  0.55055075,
#         -0.14718385, -0.06043532],
#        [-0.13538831,  0.56328689, -0.53221431, ...,  0.65621092,
#          0.02257599, -0.07771465],
#        ...,
#        [ 0.26248885, -0.35492211, -0.02220757, ..., -0.25306542,
#         -0.21777825,  0.35704504],
#        [-0.97640796, -0.3504697 , -0.07043019, ..., -0.23865754,
#         -0.18679071,  0.56896319],
#        [-0.95483118, -0.29125822, -0.05962879, ..., -0.30882354,
#          0.01606162, -0.25496429]])

# %%
score_pcaed=[]
for model_name,model_params in models.items():
    gsv_clv=GridSearchCV(model_params['model'],\
        model_params['params'],cv=5,return_train_score=False)
    gsv_clv.fit(df_pcaed,\
                df_scaled['DEATH_EVENT'])
    score_pcaed.append([model_name,gsv_clv.best_score_,\
                  gsv_clv.best_params_])
score_pcaed
# Out:
# [['svc', 0.7714285714285714, {'C': 1, 'kernel': 'linear'}],
#  ['random_forest', 0.7464285714285714, {'n_estimators': 50}],
#  ['logistic_regression', 0.7928571428571429, {'C': 1}],
#  ['gaussian_nb', 0.8071428571428572, {}],
#  ['decision_tree', 0.6892857142857143, {'criterion': 'gini'}]]

# %%
df_pcaed_score=pd.DataFrame(score_pcaed,columns=['model','score','param'])
df_pcaed_score
# Out:
#                  model     score                         param
# 0                  svc  0.771429  {'C': 1, 'kernel': 'linear'}
# 1        random_forest  0.746429          {'n_estimators': 50}
# 2  logistic_regression  0.792857                      {'C': 1}
# 3          gaussian_nb  0.807143                            {}
# 4        decision_tree  0.689286         {'criterion': 'gini'}

# %%
df_score
# Out:
#                  model  best_score                    best_params
# 0                  svc    0.775000  {'C': 20, 'kernel': 'linear'}
# 1        random_forest    0.703571           {'n_estimators': 50}
# 2  logistic_regression    0.792857                       {'C': 1}
# 3          gaussian_nb    0.792857                             {}
# 4        decision_tree    0.653571          {'criterion': 'gini'}
